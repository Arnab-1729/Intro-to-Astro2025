# %% [markdown]
# # Python Libraries 1
# # Numpy ![numpy.png](attachment:numpy.png)

# %%
import numpy

# %%
l=[1,2,3]
arr=numpy.array(l)

# %%
arr
# Out:
# array([1, 2, 3])

# %%
import numpy as np

# %%
np.array(l)
# Out:
# array([1, 2, 3])

# %%
arr_1=np.array([1,2,3])

# %%
arr_1
# Out:
# array([1, 2, 3])

# %%
arr_1+1
# Out:
# array([2, 3, 4])

# %%
arr_1*2
# Out:
# array([2, 4, 6])

# %%
l_1=[1,2,3]
l_2=[2,3,4]
l_1+l_2
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
arr_1=np.array(l_1)
arr_2=np.array(l_2)

# %%
arr_1+arr_2
# Out:
# array([3, 5, 7])

# %%
arr_1.sum()
# Out:
# 6

# %%
#Indexing
arr_1[0]
# Out:
# 1

# %%
arr_1[2]
# Out:
# 3

# %%
for i in arr_1:
    print(i)
# Out:
# 1
# 2
# 3

# %%
arr_2D=np.array([[1,1],[2,1],[3,2]])

# %%
arr_2D
# Out:
# array([[1, 1],
#        [2, 1],
#        [3, 2]])

# %%
rand_array=np.random.random(size=[3,2])

# %%
zero_array=np.zeros(shape=[3,2])
zero_array
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
zero_array
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
rand_array=np.random.random(size=[5,5])

# %%
rand_array
# Out:
# array([[0.95274214, 0.73710418, 0.20241413, 0.55099287, 0.39478249],
#        [0.45837104, 0.4345751 , 0.01072435, 0.90742233, 0.53171316],
#        [0.31051756, 0.04806199, 0.83072106, 0.0417176 , 0.97357703],
#        [0.90209397, 0.91277315, 0.32184359, 0.26478356, 0.08767272],
#        [0.65749276, 0.89417624, 0.69328144, 0.94934833, 0.57098727]])

# %%
rand_array[1,1]
# Out:
# 0.4345751007234898

# %%
rand_array[0:2,0:2]
# Out:
# array([[0.95274214, 0.73710418],
#        [0.45837104, 0.4345751 ]])

# %%
rand_array.sum(axis=1)
# Out:
# array([2.83803581, 2.34280599, 2.20459524, 2.489167  , 3.76528604])

# %%
np.array([0.4924862 , 0.58400964, 0.42182289, 0.31476085, 0.26750594]).sum()
# Out:
# 2.08058552

# %%
rand_array*10
# Out:
# array([[9.52742144, 7.3710418 , 2.0241413 , 5.50992866, 3.94782487],
#        [4.58371039, 4.34575101, 0.10724351, 9.0742233 , 5.31713165],
#        [3.10517556, 0.48061987, 8.30721059, 0.41717602, 9.73577032],
#        [9.02093968, 9.12773154, 3.2184359 , 2.64783559, 0.87672724],
#        [6.57492759, 8.94176241, 6.93281444, 9.49348332, 5.70987267]])

# %%
rand_array
# Out:
# array([[0.95274214, 0.73710418, 0.20241413, 0.55099287, 0.39478249],
#        [0.45837104, 0.4345751 , 0.01072435, 0.90742233, 0.53171316],
#        [0.31051756, 0.04806199, 0.83072106, 0.0417176 , 0.97357703],
#        [0.90209397, 0.91277315, 0.32184359, 0.26478356, 0.08767272],
#        [0.65749276, 0.89417624, 0.69328144, 0.94934833, 0.57098727]])

# %%
rand_array=np.random.random(size=100)

# %%
rand_array.sort()

# %%
rand_array
# Out:
# array([0.00275662, 0.00436625, 0.04521805, 0.07750118, 0.09402174,
#        0.1090672 , 0.11282673, 0.11461268, 0.12040106, 0.12814251,
#        0.13898748, 0.14043737, 0.15488646, 0.15581133, 0.15664602,
#        0.15978976, 0.17708458, 0.19257678, 0.24112961, 0.24902217,
#        0.25649141, 0.25837751, 0.25846508, 0.26218457, 0.27814423,
#        0.28526185, 0.2949537 , 0.31932152, 0.32423178, 0.32654387,
#        0.3280501 , 0.35237173, 0.36781985, 0.36946585, 0.37013042,
#        0.39398111, 0.39715766, 0.40967694, 0.41021913, 0.47469396,
#        0.48338221, 0.4873069 , 0.49222985, 0.49652637, 0.49964341,
#        0.50052932, 0.50199756, 0.52171517, 0.52890052, 0.52968543,
#        0.53250986, 0.55512723, 0.55556332, 0.56040173, 0.57541333,
#        0.57898854, 0.58733903, 0.5903688 , 0.59765215, 0.59797875,
#        0.60245361, 0.61511074, 0.68117825, 0.6833932 , 0.68374329,
#        0.70452193, 0.71564816, 0.72237361, 0.72522382, 0.72557344,
# ...

# %%
for row in rand_array:
    for i in row:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 for row in rand_array:
# ----> 2     for i in row:
#       3         print(i)
#
# TypeError: 'numpy.float64' object is not iterable

# %% [markdown]
# # Assistant
# This error occurs because you're trying to iterate through a NumPy float value as if it were a collection. The error suggests that `rand_array` is likely a NumPy array where each element (row) is a single float value rather than an array of values.
#
# The error happens because the inner loop `for i in row:` is trying to iterate through a single float value (`numpy.float64`), which is not iterable.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
import numpy as np

# Assuming rand_array is a NumPy array
# If rand_array is 1D (just a list of floats)
for i in rand_array:
    print(i)

# If rand_array is intended to be 2D but was created incorrectly
# First reshape it properly or create it correctly
# Example:
# rand_array = np.random.rand(3, 4)  # Creates a 2D array with shape (3, 4)
# Then iterate through it
for row in rand_array:
    for i in row:  # Now row is actually an array, not a single float
        print(i)
# Out:
# 0.002756617677518003
# 0.00436625208113639
# 0.04521805387148714
# 0.07750117503015841
# 0.0940217394918903
# 0.10906720277536586
# 0.11282672769784452
# 0.11461268270205449
# 0.12040105835968729
# 0.12814250900254165
# 0.13898747878894624
# 0.14043736925999784
# 0.1548864619407636
# 0.15581133290967264
# 0.1566460150346184
# 0.15978976374939813
# 0.17708458080712874
# 0.19257677995121225
# 0.24112960648287385
# 0.24902217444014096
# 0.2564914099498068
# 0.25837751356218974
# 0.2584650819899359
# 0.2621845725182249
# 0.27814422894865576
# 0.28526185287527694
# 0.29495370017822653
# 0.3193215224880054
# 0.32423178187939594
# 0.3265438680687748
# 0.32805010065860685
# 0.3523717278221672
# 0.3678198507066075
# 0.3694658469299149
# 0.37013042013528086
# 0.3939811089971448
# 0.3971576586602049
# 0.40967694035056346
# 0.41021913196200044
# 0.47469396210360115
# 0.483382210766627
# 0.48730689592373944
# 0.4922298459699439
# 0.49652637261544663
# 0.4996434099229966
# 0.5005293150277461
# ...

# %%
# Exercises.

# %%
x=np.linspace(0,10,100)
x.sum()
# Out:
# 500.0

# %%
#Calculate y=7x+2
y=7*x+2
y
# Out:
# array([ 2.        ,  2.70707071,  3.41414141,  4.12121212,  4.82828283,
#         5.53535354,  6.24242424,  6.94949495,  7.65656566,  8.36363636,
#         9.07070707,  9.77777778, 10.48484848, 11.19191919, 11.8989899 ,
#        12.60606061, 13.31313131, 14.02020202, 14.72727273, 15.43434343,
#        16.14141414, 16.84848485, 17.55555556, 18.26262626, 18.96969697,
#        19.67676768, 20.38383838, 21.09090909, 21.7979798 , 22.50505051,
#        23.21212121, 23.91919192, 24.62626263, 25.33333333, 26.04040404,
#        26.74747475, 27.45454545, 28.16161616, 28.86868687, 29.57575758,
#        30.28282828, 30.98989899, 31.6969697 , 32.4040404 , 33.11111111,
#        33.81818182, 34.52525253, 35.23232323, 35.93939394, 36.64646465,
#        37.35353535, 38.06060606, 38.76767677, 39.47474747, 40.18181818,
#        40.88888889, 41.5959596 , 42.3030303 , 43.01010101, 43.71717172,
#        44.42424242, 45.13131313, 45.83838384, 46.54545455, 47.25252525,
# ...

# %%
#Calculate y=x**2 for the first 10 elements
first_10=x[0:10]
y=first_10**2
y
# Out:
# array([0.        , 0.01020304, 0.04081216, 0.09182736, 0.16324865,
#        0.25507601, 0.36730946, 0.49994898, 0.65299459, 0.82644628])

# %%
x[2]*x[2]
# Out:
# 0.040812162024283234

# %%
#Define a 100 equally spaced points using linspace. And then another 100 random points. And then add x and y together
x=np.linspace(0,10,100)

y=np.random.random(size=100)

# %%
#Add x and y together and save in z
z=x+y

# %%
#Calculate the sum of of x,y and z and tell me which one is the largest

# %%
z
# Out:
# array([ 0.07066683,  0.98747776,  0.95810621,  0.3271888 ,  0.65299357,
#         1.26138506,  1.4867155 ,  1.07178066,  1.311726  ,  1.79632572,
#         1.94000233,  1.52016108,  1.94299685,  2.25186822,  2.03524573,
#         2.22249198,  1.97683192,  2.31460298,  2.47587836,  2.396304  ,
#         2.78940598,  2.19438144,  2.70663783,  2.69414092,  3.06191437,
#         3.01988149,  3.03921831,  3.23565635,  3.7788738 ,  3.11274634,
#         3.74969539,  3.78507736,  4.06167912,  3.38070789,  3.46830262,
#         4.02875912,  3.95746801,  3.79537971,  4.15659643,  4.56357399,
#         4.29457494,  4.25227921,  4.99914565,  5.2782378 ,  4.87118074,
#         4.94096811,  5.43718953,  4.98989301,  5.73953222,  5.5201694 ,
#         5.28659018,  6.08589208,  6.20453753,  6.03310196,  6.25696014,
#         6.14601464,  6.57451979,  6.12541526,  6.14778819,  6.12870718,
#         6.53825899,  6.27060466,  7.22692182,  6.91574377,  6.54813945,
# ...

# %%
print(x.sum())
print(y.sum())
print(z.sum())
# Out:
# 500.0
# 47.117912498791064
# 547.117912498791
